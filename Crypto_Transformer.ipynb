# %%
import numpy as np
import pandas as pd
import os, datetime
import tensorflow as tf
from tensorflow import keras
from keras.layers import *
from keras.models import *
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
plt.style.use('seaborn')
# Out:
# <ipython-input-30-d31a1866d9ac>:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.config.experimental.set_visible_devices(physical_devices[0], 'GPU')

# %% [markdown]
# # Bitcoin History Data

# %%
# !pip install alpaca-trade-api
# !pip install alpaca-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting alpaca-trade-api
#   Downloading alpaca_trade_api-3.0.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (1.5.3)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (1.22.4)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (2.27.1)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (1.26.15)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (1.5.1)
# Collecting websockets<11,>=9.0 (from alpaca-trade-api)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 6.2 MB/s eta 0:00:00
# Collecting msgpack==1.0.3 (from alpaca-trade-api)
#   Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 18.3 MB/s eta 0:00:00
# Collecting aiohttp==3.8.1 (from alpaca-trade-api)
#   Downloading aiohttp-3.8.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (6.0)
# Collecting deprecation==2.1.0 (from alpaca-trade-api)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (23.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp==3.8.1->alpaca-trade-api)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp==3.8.1->alpaca-trade-api)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp==3.8.1->alpaca-trade-api)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 36.6 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp==3.8.1->alpaca-trade-api)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 23.0 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp==3.8.1->alpaca-trade-api)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation==2.1.0->alpaca-trade-api) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.18.1->alpaca-trade-api) (1.16.0)
# Installing collected packages: msgpack, websockets, multidict, frozenlist, deprecation, async-timeout, yarl, aiosignal, aiohttp, alpaca-trade-api
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.5
#     Uninstalling msgpack-1.0.5:
#       Successfully uninstalled msgpack-1.0.5
# Successfully installed aiohttp-3.8.1 aiosignal-1.3.1 alpaca-trade-api-3.0.0 async-timeout-4.0.2 deprecation-2.1.0 frozenlist-1.3.3 msgpack-1.0.3 multidict-6.0.4 websockets-10.4 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting alpaca-py
#   Downloading alpaca_py-0.8.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.8/96.8 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (1.0.3)
# Requirement already satisfied: pandas<2.0.0,>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (1.5.3)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (1.10.7)
# Requirement already satisfied: requests<3.0.0,>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (2.27.1)
# Collecting sseclient-py<2.0.0,>=1.7.2 (from alpaca-py)
#   Downloading sseclient_py-1.7.2-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: websockets<11.0,>=10.2 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (10.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (1.22.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0.0,>=1.9.0->alpaca-py) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.5->alpaca-py) (1.16.0)
# Installing collected packages: sseclient-py, alpaca-py
# Successfully installed alpaca-py-0.8.2 sseclient-py-1.7.2

# %%
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame
#  Get historical Bitcoin prices
client = CryptoHistoricalDataClient()
request_params = CryptoBarsRequest(
                        symbol_or_symbols=["BTC/USD"],
                        timeframe=TimeFrame.Hour,
                        start="2020-01-01 00:00:00"
                 )
bars = client.get_crypto_bars(request_params)
bars_df = bars.df
bars_df
# Out:
#                                        open      high       low     close  \
# symbol  timestamp
# BTC/USD 2021-01-01 06:00:00+00:00  29255.71  29338.25  29153.55  29234.15
#         2021-01-01 07:00:00+00:00  29235.61  29236.95  28905.00  29162.50
#         2021-01-01 08:00:00+00:00  29162.50  29248.52  28948.86  29076.77
#         2021-01-01 09:00:00+00:00  29075.31  29372.32  29058.05  29284.92
#         2021-01-01 10:00:00+00:00  29291.54  29400.00  29232.16  29286.63
# ...                                     ...       ...       ...       ...
#         2023-05-10 17:00:00+00:00  28249.13  28280.83  26900.00  27650.00
#         2023-05-10 18:00:00+00:00  27644.36  27686.08  27518.75  27585.51
#         2023-05-10 19:00:00+00:00  27582.79  27905.82  27555.72  27810.38
#         2023-05-10 20:00:00+00:00  27812.11  28079.25  27775.00  27963.68
#         2023-05-10 21:00:00+00:00  27965.62  27969.21  27841.40  27852.99
#
#                                        volume  trade_count          vwap
# symbol  timestamp
# BTC/USD 2021-01-01 06:00:00+00:00   42.244289       1243.0  29237.240312
#         2021-01-01 07:00:00+00:00   34.506038       1070.0  29078.423185
#         2021-01-01 08:00:00+00:00   27.596804       1110.0  29091.465155
#         2021-01-01 09:00:00+00:00   20.694200        880.0  29248.730924
#         2021-01-01 10:00:00+00:00   16.617646        742.0  29338.609132
# ...                                       ...          ...           ...
#         2023-05-10 17:00:00+00:00  677.655428      17830.0  27405.103213
#         2023-05-10 18:00:00+00:00  276.511659       5074.0  27596.475260
#         2023-05-10 19:00:00+00:00  238.420953       6162.0  27773.723931
#         2023-05-10 20:00:00+00:00  227.919227       6038.0  27966.605447
#         2023-05-10 21:00:00+00:00   44.753810       1180.0  27895.547231
#
# [20622 rows x 7 columns]

# %%
bars_df = bars_df.reset_index()

# %%
bars_df['timestamp'] = pd.to_datetime(bars_df['timestamp'])
bars_df['timestamp'] = bars_df['timestamp'].dt.strftime('%Y-%m-%d')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/UChicago_Project/Machine_Learning/btc_price.csv'
bars_df.to_csv(path, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6056be7ae7ed> in <cell line: 2>()
#       1 path = '/content/drive/MyDrive/UChicago_Project/Machine_Learning/btc_price.csv'
# ----> 2 bars_df.to_csv(path, index=False)
#
# NameError: name 'bars_df' is not defined

# %%
# load data
path = '/content/drive/MyDrive/UChicago_Project/Machine_Learning/btc_price.csv'
bars_df = pd.read_csv(path)

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("BTC Close Price and Volume", fontsize=20)
st.set_y(0.92)

ax1 = fig.add_subplot(211)
ax1.plot(bars_df['close'], label='BTC Close Price')
ax1.set_xticks(range(0, bars_df.shape[0], 1000))
ax1.set_xticklabels(bars_df['timestamp'].loc[::1000], rotation = 20)
ax1.set_ylabel('Close Price', fontsize=18)
ax1.legend(loc="upper left", fontsize=12)

ax2 = fig.add_subplot(212)
ax2.plot(bars_df['volume'], label='BTC Volume')
ax2.set_xticks(range(0, bars_df.shape[0], 1000))
ax2.set_xticklabels(bars_df['timestamp'].loc[::1000], rotation = 20)
ax2.set_ylabel('Volume', fontsize=18)
ax2.legend(loc="upper left", fontsize=12)

# %% [markdown]
# ## Moving Average = 24

# %%
bars_df[['open', 'high', 'low', 'close', 'volume']] = bars_df[['open', 'high', 'low', 'close', 'volume']].rolling(24).mean()

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("BTC Close Price and Volume", fontsize=20)
st.set_y(0.92)

ax1 = fig.add_subplot(211)
ax1.plot(bars_df['close'], label='BTC Close Price')
ax1.set_xticks(range(0, bars_df.shape[0], 1000))
ax1.set_xticklabels(bars_df['timestamp'].loc[::1000], rotation = 20)
ax1.set_ylabel('Close Price', fontsize=18)
ax1.legend(loc="upper left", fontsize=12)

ax2 = fig.add_subplot(212)
ax2.plot(bars_df['volume'], label='BTC Volume')
ax2.set_xticks(range(0, bars_df.shape[0], 1000))
ax2.set_xticklabels(bars_df['timestamp'].loc[::1000], rotation = 20)
ax2.set_ylabel('Volume', fontsize=18)
ax2.legend(loc="upper left", fontsize=12)

# %% [markdown]
# # Change to Returns Value

# %%
df = pd.DataFrame()
df['open'] = bars_df['open'].pct_change()
df['high'] = bars_df['high'].pct_change()
df['low'] = bars_df['low'].pct_change()
df['close'] = bars_df['close'].pct_change()
df['volume'] = bars_df['volume'].pct_change()

# %%
df = df.dropna()
df
# Out:
#            open      high       low     close    volume
# 24     0.000601  0.000683  0.000576  0.000804  0.016066
# 25     0.000802  0.000924  0.001147  0.000953  0.005058
# 26     0.000950  0.000950  0.001106  0.001185  0.010103
# 27     0.001189  0.000824  0.000845  0.000583  0.021834
# 28     0.000550  0.000695  0.000461  0.000649  0.017350
# ...         ...       ...       ...       ...       ...
# 20592 -0.000213 -0.000208 -0.000332 -0.000143  0.006968
# 20593 -0.000134 -0.000078  0.000071  0.000144 -0.039699
# 20594  0.000140  0.000082  0.000269  0.000012 -0.100099
# 20595  0.000004 -0.000165  0.000087 -0.000198 -0.049865
# 20596 -0.000174 -0.000927 -0.000303 -0.001030 -0.122168
#
# [20573 rows x 5 columns]

# %%
# last 20 percentage
times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))]
last_20pct
# Out:
# 16483

# %%
# Normalize with 20 percentage
min_return = min(df[(df.index < last_20pct)][['open', 'high', 'low', 'close']].min(axis=0))
max_return = max(df[(df.index < last_20pct)][['open', 'high', 'low', 'close']].max(axis=0))

# Min-max normalize price columns (0-1 range)
df['open'] = (df['open'] - min_return) / (max_return - min_return)
df['high'] = (df['high'] - min_return) / (max_return - min_return)
df['low'] = (df['low'] - min_return) / (max_return - min_return)
df['close'] = (df['close'] - min_return) / (max_return - min_return)

# %%
min_volume = df[(df.index < last_20pct)]['volume'].min(axis=0)
max_volume = df[(df.index < last_20pct)]['volume'].max(axis=0)

# Min-max normalize volume columns (0-1 range)
df.loc[:, 'volume'] = (df.loc[:,'volume'] - min_volume) / (max_volume - min_volume)

# %%
df
# Out:
#            open      high       low     close    volume
# 24     0.491942  0.493055  0.491609  0.494710  0.324470
# 25     0.494683  0.496343  0.499385  0.496739  0.313973
# 26     0.496705  0.496700  0.498821  0.499907  0.318783
# 27     0.499952  0.494981  0.495275  0.491696  0.329969
# 28     0.491253  0.493226  0.490035  0.492598  0.325694
# ...         ...       ...       ...       ...       ...
# 20592  0.480850  0.480913  0.479230  0.481806  0.315794
# 20593  0.481929  0.482693  0.484714  0.485719  0.271295
# 20594  0.485663  0.484867  0.487420  0.483910  0.213702
# 20595  0.483803  0.481501  0.484938  0.481053  0.261601
# 20596  0.481375  0.471116  0.479619  0.469719  0.192657
#
# [20573 rows x 5 columns]

# %%
fig = plt.figure(figsize=(15,12))

# close price
ax1 = fig.add_subplot(211)
ax1.plot(np.arange(df.shape[0]), df['close'])


ax1.set_xlabel('Date')
ax1.set_ylabel('Normalized Closing Returns')
ax1.set_title("Close Price Percentage Changes", fontsize=18)
ax1.legend(loc="best", fontsize=12)

# volume
ax2 = fig.add_subplot(212)
ax2.plot(np.arange(df.shape[0]), df['volume'])

ax2.set_xlabel('Date')
ax2.set_ylabel('Normalized Volume Changes')
ax2.set_title("Volume Percentage Changes", fontsize=18)
ax2.legend(loc="best", fontsize=12)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Train/Test Split

# %%
df_train = df[(df.index < last_20pct)]
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# %%
# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))
# Out:
# Training data shape: (16459, 5)
# Validation data shape: (2057, 5)
# Test data shape: (2057, 5)

# %%
fig = plt.figure(figsize=(15,20))

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='BTC Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('BTC Closing Returns')
ax11.legend(loc="best", fontsize=12)

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='BTC Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')
ax21.legend(loc="best", fontsize=12)

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='BTC Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('BTC Closing Returns')
ax31.legend(loc="best", fontsize=12)

# %% [markdown]
# # Input / Target variable

# %%
# Training data
seq_len=128
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 3][i]) # Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape, y_train.shape
# Out:
# ((16331, 128, 5), (16331,))

# %%
# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 3][i])
X_val, y_val = np.array(X_val), np.array(y_val)

# %%
X_val.shape
# Out:
# (1929, 128, 5)

# %%
# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 3][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
X_test.shape
# Out:
# (1929, 128, 5)

# %% [markdown]
# # Time Embeddings

# %%
class Time2Vector(Layer):
  def __init__(self, seq_len, **kwargs):
    # inherit from Layer
    super(Time2Vector, self).__init__()
    self.seq_len = seq_len

  def build(self, input_shape):
    # Initialize weights and biases with shape (batch, seq_len)
    # for linear pattern
    self.weights_linear = self.add_weight(name='weight_linear',
                                shape=(int(self.seq_len),), # shape is same as the sequence length
                                initializer='uniform', # randomized between 0-1
                                trainable=True)
    
    self.bias_linear = self.add_weight(name='bias_linear',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)
    # for periodic pattern
    self.weights_periodic = self.add_weight(name='weight_periodic',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)

    self.bias_periodic = self.add_weight(name='bias_periodic',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)

  def call(self, x):
    # Calculate linear and periodic time features
    x = tf.math.reduce_mean(x[:,:,:4], axis=-1) 
    time_linear = self.weights_linear * x + self.bias_linear # Linear time feature
    time_linear = tf.expand_dims(time_linear, axis=-1) # Add dimension (batch, seq_len, 1)
    
    time_periodic = tf.math.sin(tf.multiply(x, self.weights_periodic) + self.bias_periodic)
    time_periodic = tf.expand_dims(time_periodic, axis=-1) # Add dimension (batch, seq_len, 1)
    return tf.concat([time_linear, time_periodic], axis=-1) # shape = (batch, seq_len, 2)
   
  def get_config(self): 
    # saving and loading model with custom layer
    config = super().get_config().copy()
    config.update({'seq_len': self.seq_len})
    return config

# %% [markdown]
# # Hyperparameter

# %%
batch_size = 32
seq_len = 128

d_k = 256
d_v = 256
n_heads = 18
ff_dim = 256

# %% [markdown]
# # Transformer Model

# %%
class SingleAttention(Layer):
  def __init__(self, d_k, d_v):
    super(SingleAttention, self).__init__()
    self.d_k = d_k
    self.d_v = d_v

  def build(self, input_shape):
    # choose glorot_uniform as weight initialization to control variance
    self.query = Dense(self.d_k, 
                       input_shape=input_shape, 
                       kernel_initializer='glorot_uniform', 
                       bias_initializer='glorot_uniform')
    
    self.key = Dense(self.d_k, 
                     input_shape=input_shape, 
                     kernel_initializer='glorot_uniform', 
                     bias_initializer='glorot_uniform')
    
    self.value = Dense(self.d_v, 
                       input_shape=input_shape, 
                       kernel_initializer='glorot_uniform', 
                       bias_initializer='glorot_uniform')

  def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
    q = self.query(inputs[0])
    k = self.key(inputs[1])

    attn_weights = tf.matmul(q, k, transpose_b=True)
    attn_weights = tf.map_fn(lambda x: x/np.sqrt(self.d_k), attn_weights)
    attn_weights = tf.nn.softmax(attn_weights, axis=-1)
    
    v = self.value(inputs[2])
    attn_out = tf.matmul(attn_weights, v)
    return attn_out

# %%
class MultiAttention(Layer):
  def __init__(self, d_k, d_v, n_heads):
    super(MultiAttention, self).__init__()
    self.d_k = d_k
    self.d_v = d_v
    self.n_heads = n_heads
    self.attn_heads = list()

  def build(self, input_shape):
    for n in range(self.n_heads):
      self.attn_heads.append(SingleAttention(self.d_k, self.d_v))  
    
    # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1]=7 
    self.linear = Dense(input_shape[0][-1], 
                        input_shape=input_shape, 
                        kernel_initializer='glorot_uniform', 
                        bias_initializer='glorot_uniform')

  def call(self, inputs):
    attn = [self.attn_heads[i](inputs) for i in range(self.n_heads)]
    concat_attn = tf.concat(attn, axis=-1)
    multi_linear = self.linear(concat_attn)
    return multi_linear

# %%
class TransformerEncoder(Layer):
  def __init__(self, d_k, d_v, n_heads, ff_dim, dropout=0.1, **kwargs):
    super(TransformerEncoder, self).__init__()
    self.d_k = d_k
    self.d_v = d_v
    self.n_heads = n_heads
    self.ff_dim = ff_dim
    self.attn_heads = list()
    self.dropout_rate = dropout

  def build(self, input_shape):
    self.attn_multi = MultiAttention(self.d_k, self.d_v, self.n_heads)
    self.attn_dropout = Dropout(self.dropout_rate)
    self.attn_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

    self.ff_conv1D_1 = Conv1D(filters=self.ff_dim, kernel_size=1, activation='relu')
    # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1] = 7 
    self.ff_conv1D_2 = Conv1D(filters=input_shape[0][-1], kernel_size=1) 
    self.ff_dropout = Dropout(self.dropout_rate)
    self.ff_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)    
  
  def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
    attn_layer = self.attn_multi(inputs)
    attn_layer = self.attn_dropout(attn_layer)
    attn_layer = self.attn_normalize(inputs[0] + attn_layer)

    ff_layer = self.ff_conv1D_1(attn_layer)
    ff_layer = self.ff_conv1D_2(ff_layer)
    ff_layer = self.ff_dropout(ff_layer)
    ff_layer = self.ff_normalize(inputs[0] + ff_layer)
    return ff_layer 

  def get_config(self): 
    # saving and loading model with custom layer
    config = super().get_config().copy()
    config.update({'d_k': self.d_k,
                   'd_v': self.d_v,
                   'n_heads': self.n_heads,
                   'ff_dim': self.ff_dim,
                   'attn_heads': self.attn_heads,
                   'dropout_rate': self.dropout_rate})
    return config

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def create_model():
  '''Initialize time and transformer layers'''
  time_embedding = Time2Vector(seq_len)
  attn_layer1 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
  attn_layer2 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
  attn_layer3 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)

  '''Construct model'''
  in_seq = Input(shape=(seq_len, 5))
  x = time_embedding(in_seq)
  x = Concatenate(axis=-1)([in_seq, x])
  x = attn_layer1((x, x, x))
  x = attn_layer2((x, x, x))
  x = attn_layer3((x, x, x))
  x = GlobalAveragePooling1D(data_format='channels_first')(x)
  x = Dropout(0.1)(x)
  x = Dense(64, activation='relu')(x)
  x = Dropout(0.1)(x)
  out = Dense(1, activation='linear')(x)

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss='mse', optimizer='adam', metrics=['mae', 'mape'])
  return model


model = create_model()
model.summary()

path = '/content/gdrive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding.hdf5'

callback = tf.keras.callbacks.ModelCheckpoint(path, 
                                              monitor='val_loss', 
                                              save_best_only=True, 
                                              verbose=1)

history = model.fit(X_train, y_train, 
                    batch_size=batch_size, 
                    epochs=20, 
                    callbacks=[callback],
                    validation_data=(X_val, y_val))
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 5)]     0           []
#
#  time2_vector_2 (Time2Vector)   (None, 128, 2)       512         ['input_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 128, 7)       0           ['input_2[0][0]',
#                                                                   'time2_vector_2[0][0]']
#
#  transformer_encoder_6 (Transfo  (None, 128, 7)      146730      ['concatenate_1[0][0]',
#  rmerEncoder)                                                     'concatenate_1[0][0]',
#                                                                   'concatenate_1[0][0]']
#
#  transformer_encoder_7 (Transfo  (None, 128, 7)      146730      ['transformer_encoder_6[0][0]',
#  rmerEncoder)                                                     'transformer_encoder_6[0][0]',
#                                                                   'transformer_encoder_6[0][0]']
#
#  transformer_encoder_8 (Transfo  (None, 128, 7)      146730      ['transformer_encoder_7[0][0]',
#  rmerEncoder)                                                     'transformer_encoder_7[0][0]',
#                                                                   'transformer_encoder_7[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 128)         0           ['transformer_encoder_8[0][0]']
#  obalAveragePooling1D)
#
#  dropout_2 (Dropout)            (None, 128)          0           ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 64)           0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            65          ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 449,023
# Trainable params: 449,023
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0463 - mape: 9.6085
# Epoch 1: val_loss improved from inf to 0.00017, saving model to /content/gdrive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding.hdf5
# 511/511 [==============================] - 599s 995ms/step - loss: 0.0066 - mae: 0.0463 - mape: 9.6085 - val_loss: 1.6899e-04 - val_mae: 0.0088 - val_mape: 1.7773
# Epoch 2/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0014 - mae: 0.0298 - mape: 6.1946
# Epoch 2: val_loss did not improve from 0.00017
# 511/511 [==============================] - 495s 969ms/step - loss: 0.0014 - mae: 0.0298 - mape: 6.1946 - val_loss: 2.3314e-04 - val_mae: 0.0114 - val_mape: 2.3107
# Epoch 3/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0285 - mape: 5.9248
# Epoch 3: val_loss did not improve from 0.00017
# 511/511 [==============================] - 493s 964ms/step - loss: 0.0013 - mae: 0.0285 - mape: 5.9248 - val_loss: 5.8792e-04 - val_mae: 0.0214 - val_mape: 4.3613
# Epoch 4/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0263 - mape: 5.4815
# Epoch 4: val_loss improved from 0.00017 to 0.00014, saving model to /content/gdrive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding.hdf5
# 511/511 [==============================] - 495s 968ms/step - loss: 0.0011 - mae: 0.0263 - mape: 5.4815 - val_loss: 1.4007e-04 - val_mae: 0.0081 - val_mape: 1.6531
# Epoch 5/20
# 511/511 [==============================] - ETA: 0s - loss: 9.9431e-04 - mae: 0.0246 - mape: 5.1140
# Epoch 5: val_loss did not improve from 0.00014
# 511/511 [==============================] - 491s 961ms/step - loss: 9.9431e-04 - mae: 0.0246 - mape: 5.1140 - val_loss: 1.4227e-04 - val_mae: 0.0075 - val_mape: 1.5329
# Epoch 6/20
# 511/511 [==============================] - ETA: 0s - loss: 8.7710e-04 - mae: 0.0229 - mape: 4.7634
# Epoch 6: val_loss did not improve from 0.00014
# 511/511 [==============================] - 496s 972ms/step - loss: 8.7710e-04 - mae: 0.0229 - mape: 4.7634 - val_loss: 1.4327e-04 - val_mae: 0.0084 - val_mape: 1.7204
# Epoch 7/20
# 511/511 [==============================] - ETA: 0s - loss: 7.7450e-04 - mae: 0.0213 - mape: 4.4459
# Epoch 7: val_loss did not improve from 0.00014
# 511/511 [==============================] - 491s 959ms/step - loss: 7.7450e-04 - mae: 0.0213 - mape: 4.4459 - val_loss: 1.4133e-04 - val_mae: 0.0082 - val_mape: 1.6811
# Epoch 8/20
# 511/511 [==============================] - ETA: 0s - loss: 6.9475e-04 - mae: 0.0200 - mape: 4.1679
# Epoch 8: val_loss did not improve from 0.00014
# 511/511 [==============================] - 489s 956ms/step - loss: 6.9475e-04 - mae: 0.0200 - mape: 4.1679 - val_loss: 1.5348e-04 - val_mae: 0.0080 - val_mape: 1.6285
# Epoch 9/20
# 511/511 [==============================] - ETA: 0s - loss: 6.3602e-04 - mae: 0.0189 - mape: 3.9470
# Epoch 9: val_loss did not improve from 0.00014
# 511/511 [==============================] - 505s 988ms/step - loss: 6.3602e-04 - mae: 0.0189 - mape: 3.9470 - val_loss: 2.0560e-04 - val_mae: 0.0103 - val_mape: 2.0923
# Epoch 10/20
# 511/511 [==============================] - ETA: 0s - loss: 4.9425e-04 - mae: 0.0166 - mape: 3.4687
# Epoch 10: val_loss improved from 0.00014 to 0.00010, saving model to /content/gdrive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding.hdf5
# 511/511 [==============================] - 489s 956ms/step - loss: 4.9425e-04 - mae: 0.0166 - mape: 3.4687 - val_loss: 1.0192e-04 - val_mae: 0.0086 - val_mape: 1.7730
# Epoch 11/20
# 511/511 [==============================] - ETA: 0s - loss: 2.3364e-04 - mae: 0.0116 - mape: 2.4064
# Epoch 11: val_loss did not improve from 0.00010
# 511/511 [==============================] - 506s 991ms/step - loss: 2.3364e-04 - mae: 0.0116 - mape: 2.4064 - val_loss: 6.0392e-04 - val_mae: 0.0234 - val_mape: 4.8447
# Epoch 12/20
# 511/511 [==============================] - ETA: 0s - loss: 1.7619e-04 - mae: 0.0100 - mape: 2.0858
# Epoch 12: val_loss did not improve from 0.00010
# 511/511 [==============================] - 487s 953ms/step - loss: 1.7619e-04 - mae: 0.0100 - mape: 2.0858 - val_loss: 0.0013 - val_mae: 0.0355 - val_mape: 7.3364
# Epoch 13/20
# 511/511 [==============================] - ETA: 0s - loss: 1.4659e-04 - mae: 0.0090 - mape: 1.8705
# Epoch 13: val_loss did not improve from 0.00010
# 511/511 [==============================] - 492s 964ms/step - loss: 1.4659e-04 - mae: 0.0090 - mape: 1.8705 - val_loss: 0.0014 - val_mae: 0.0358 - val_mape: 7.3861
# Epoch 14/20
# 511/511 [==============================] - ETA: 0s - loss: 1.3872e-04 - mae: 0.0087 - mape: 1.8015
# Epoch 14: val_loss did not improve from 0.00010
# 511/511 [==============================] - 489s 957ms/step - loss: 1.3872e-04 - mae: 0.0087 - mape: 1.8015 - val_loss: 5.1107e-04 - val_mae: 0.0211 - val_mape: 4.3602
# Epoch 15/20
# 511/511 [==============================] - ETA: 0s - loss: 1.2751e-04 - mae: 0.0083 - mape: 1.7278
# Epoch 15: val_loss did not improve from 0.00010
# 511/511 [==============================] - 492s 963ms/step - loss: 1.2751e-04 - mae: 0.0083 - mape: 1.7278 - val_loss: 5.7923e-04 - val_mae: 0.0229 - val_mape: 4.7402
# Epoch 16/20
# 511/511 [==============================] - ETA: 0s - loss: 1.1835e-04 - mae: 0.0080 - mape: 1.6609
# Epoch 16: val_loss did not improve from 0.00010
# 511/511 [==============================] - 493s 965ms/step - loss: 1.1835e-04 - mae: 0.0080 - mape: 1.6609 - val_loss: 8.2327e-04 - val_mae: 0.0278 - val_mape: 5.7339
# Epoch 17/20
# 511/511 [==============================] - ETA: 0s - loss: 1.1468e-04 - mae: 0.0079 - mape: 1.6349
# Epoch 17: val_loss did not improve from 0.00010
# 511/511 [==============================] - 491s 961ms/step - loss: 1.1468e-04 - mae: 0.0079 - mape: 1.6349 - val_loss: 8.5590e-04 - val_mae: 0.0283 - val_mape: 5.8401
# Epoch 18/20
# 511/511 [==============================] - ETA: 0s - loss: 1.0605e-04 - mae: 0.0075 - mape: 1.5563
# Epoch 18: val_loss did not improve from 0.00010
# 511/511 [==============================] - 489s 958ms/step - loss: 1.0605e-04 - mae: 0.0075 - mape: 1.5563 - val_loss: 7.7713e-04 - val_mae: 0.0271 - val_mape: 5.5899
# Epoch 19/20
# 511/511 [==============================] - ETA: 0s - loss: 1.0397e-04 - mae: 0.0074 - mape: 1.5492
# Epoch 19: val_loss did not improve from 0.00010
# 511/511 [==============================] - 492s 963ms/step - loss: 1.0397e-04 - mae: 0.0074 - mape: 1.5492 - val_loss: 0.0012 - val_mae: 0.0339 - val_mape: 6.9904
# Epoch 20/20
# 511/511 [==============================] - ETA: 0s - loss: 1.0011e-04 - mae: 0.0072 - mape: 1.5009
# Epoch 20: val_loss did not improve from 0.00010
# 511/511 [==============================] - 489s 957ms/step - loss: 1.0011e-04 - mae: 0.0072 - mape: 1.5009 - val_loss: 6.6863e-04 - val_mae: 0.0250 - val_mape: 5.1589

# %%
path = '/content/drive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding.hdf5'
model = tf.keras.models.load_model(path,
                                   custom_objects={'Time2Vector': Time2Vector, 
                                                   'SingleAttention': SingleAttention,
                                                   'MultiAttention': MultiAttention,
                                                   'TransformerEncoder': TransformerEncoder})

# %%
#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))
# Out:
# 511/511 [==============================] - 129s 239ms/step
# 61/61 [==============================] - 15s 238ms/step
# 61/61 [==============================] - 14s 238ms/step
#
# Evaluation metrics
# Training Data - Loss: 0.0004, MAE: 0.0156, MAPE: 3.2811
# Validation Data - Loss: 0.0002, MAE: 0.0133, MAPE: 2.7563
# Test Data - Loss: 0.0003, MAE: 0.0141, MAPE: 2.9200

# %%
fig = plt.figure(figsize=(15,20))

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='BTC Closing Returns')
ax11.plot(np.arange(seq_len, train_pred.shape[0]+seq_len), train_pred, linewidth=3, label='Predicted BTC Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('BTC Closing Returns')
ax11.legend(loc="best", fontsize=12)

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='BTC Closing Returns')
ax21.plot(np.arange(seq_len, val_pred.shape[0]+seq_len), val_pred, linewidth=3, label='Predicted BTC Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')
ax21.legend(loc="best", fontsize=12)

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='BTC Closing Returns')
ax31.plot(np.arange(seq_len, test_pred.shape[0]+seq_len), test_pred, linewidth=3, label='Predicted BTC Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('BTC Closing Returns')
ax31.legend(loc="best", fontsize=12)

# %%
fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Moving Average - Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
ax1.plot(history.history['loss'], label='Training loss (MSE)')
ax1.set_title("Model loss", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (MSE)')
ax1.legend(loc="best", fontsize=12)

#Plot MAE
ax2 = fig.add_subplot(312)
ax2.plot(history.history['mae'], label='Training MAE')
ax2.set_title("Model metric - Mean absolute error (MAE)", fontsize=18)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean absolute error (MAE)')
ax2.legend(loc="best", fontsize=12)

#Plot MAPE
ax3 = fig.add_subplot(313)
ax3.plot(history.history['mape'], label='Training MAPE')
ax3.set_title("Model metric - Mean absolute percentage error (MAPE)", fontsize=18)
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Mean absolute percentage error (MAPE)')
ax3.legend(loc="best", fontsize=12)

# %%
history.history['val_loss']
# Out:
# [0.00016763355233706534,
#  0.00022808354697190225,
#  0.00013820263848174363,
#  0.0001744133187457919,
#  0.00026067133876495063,
#  0.00017211130762007087,
#  0.0001806224463507533,
#  0.00015034974785521626,
#  0.00015697148046456277,
#  0.0005222075269557536,
#  0.0007331653614528477,
#  0.0004288779164198786,
#  0.0004926572437398136,
#  0.00038834166480228305,
#  0.0006743972771801054,
#  0.0005821330123580992,
#  0.00035766229848377407,
#  0.00011888162407558411,
#  0.0001295777183258906,
#  0.0002450407191645354]

# %%
fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Moving Average - Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
#ax1.plot(history.history['loss'][:9], label='Training loss (MSE)')
ax1.plot(history.history['val_loss'], label='Validation loss (MSE)')
ax1.set_title("Model loss", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (MSE)')
ax1.legend(loc="best", fontsize=12)

#Plot MAE
ax2 = fig.add_subplot(312)
ax2.plot(history.history['val_mae'], label='Validation MAE')
ax2.set_title("Model metric - Mean absolute error (MAE)", fontsize=18)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean absolute error (MAE)')
ax2.legend(loc="best", fontsize=12)

#Plot MAPE
ax3 = fig.add_subplot(313)
ax3.plot(history.history['val_mape'], label='Validation MAPE')
ax3.set_title("Model metric - Mean absolute percentage error (MAPE)", fontsize=18)
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Mean absolute percentage error (MAPE)')
ax3.legend(loc="best", fontsize=12)

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    dpi=96,)

# %% [markdown]
# # Attention head = 12, Drop out = 0.2

# %%
batch_size = 32
seq_len = 128

d_k = 256
d_v = 256
n_heads = 12
ff_dim = 256

# %%
class SingleAttention(Layer):
  def __init__(self, d_k, d_v):
    super(SingleAttention, self).__init__()
    self.d_k = d_k
    self.d_v = d_v

  def build(self, input_shape):
    # choose glorot_uniform as weight initialization to control variance
    self.query = Dense(self.d_k, 
                       input_shape=input_shape, 
                       kernel_initializer='glorot_uniform', 
                       bias_initializer='glorot_uniform')
    
    self.key = Dense(self.d_k, 
                     input_shape=input_shape, 
                     kernel_initializer='glorot_uniform', 
                     bias_initializer='glorot_uniform')
    
    self.value = Dense(self.d_v, 
                       input_shape=input_shape, 
                       kernel_initializer='glorot_uniform', 
                       bias_initializer='glorot_uniform')

  def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
    q = self.query(inputs[0])
    k = self.key(inputs[1])

    attn_weights = tf.matmul(q, k, transpose_b=True)
    attn_weights = tf.map_fn(lambda x: x/np.sqrt(self.d_k), attn_weights)
    attn_weights = tf.nn.softmax(attn_weights, axis=-1)
    
    v = self.value(inputs[2])
    attn_out = tf.matmul(attn_weights, v)
    return attn_out

# %%
class MultiAttention(Layer):
  def __init__(self, d_k, d_v, n_heads):
    super(MultiAttention, self).__init__()
    self.d_k = d_k
    self.d_v = d_v
    self.n_heads = n_heads
    self.attn_heads = list()

  def build(self, input_shape):
    for n in range(self.n_heads):
      self.attn_heads.append(SingleAttention(self.d_k, self.d_v))  
    
    # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1]=7 
    self.linear = Dense(input_shape[0][-1], 
                        input_shape=input_shape, 
                        kernel_initializer='glorot_uniform', 
                        bias_initializer='glorot_uniform')

  def call(self, inputs):
    attn = [self.attn_heads[i](inputs) for i in range(self.n_heads)]
    concat_attn = tf.concat(attn, axis=-1)
    multi_linear = self.linear(concat_attn)
    return multi_linear

# %%
class TransformerEncoder(Layer):
  def __init__(self, d_k, d_v, n_heads, ff_dim, dropout=0.1, **kwargs):
    super(TransformerEncoder, self).__init__()
    self.d_k = d_k
    self.d_v = d_v
    self.n_heads = n_heads
    self.ff_dim = ff_dim
    self.attn_heads = list()
    self.dropout_rate = dropout

  def build(self, input_shape):
    self.attn_multi = MultiAttention(self.d_k, self.d_v, self.n_heads)
    self.attn_dropout = Dropout(self.dropout_rate)
    self.attn_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

    self.ff_conv1D_1 = Conv1D(filters=self.ff_dim, kernel_size=1, activation='relu')
    # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1] = 7 
    self.ff_conv1D_2 = Conv1D(filters=input_shape[0][-1], kernel_size=1) 
    self.ff_dropout = Dropout(self.dropout_rate)
    self.ff_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)    
  
  def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
    attn_layer = self.attn_multi(inputs)
    attn_layer = self.attn_dropout(attn_layer)
    attn_layer = self.attn_normalize(inputs[0] + attn_layer)

    ff_layer = self.ff_conv1D_1(attn_layer)
    ff_layer = self.ff_conv1D_2(ff_layer)
    ff_layer = self.ff_dropout(ff_layer)
    ff_layer = self.ff_normalize(inputs[0] + ff_layer)
    return ff_layer 

  def get_config(self): 
    # saving and loading model with custom layer
    config = super().get_config().copy()
    config.update({'d_k': self.d_k,
                   'd_v': self.d_v,
                   'n_heads': self.n_heads,
                   'ff_dim': self.ff_dim,
                   'attn_heads': self.attn_heads,
                   'dropout_rate': self.dropout_rate})
    return config

# %%
def create_model():
  '''Initialize time and transformer layers'''
  time_embedding = Time2Vector(seq_len)
  attn_layer1 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
  attn_layer2 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
  attn_layer3 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)

  '''Construct model'''
  in_seq = Input(shape=(seq_len, 5))
  x = time_embedding(in_seq)
  x = Concatenate(axis=-1)([in_seq, x])
  x = attn_layer1((x, x, x))
  x = attn_layer2((x, x, x))
  x = attn_layer3((x, x, x))
  x = GlobalAveragePooling1D(data_format='channels_first')(x)
  x = Dropout(0.1)(x)
  x = Dense(64, activation='relu')(x)
  x = Dropout(0.1)(x)
  out = Dense(1, activation='linear')(x)

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss='mse', optimizer='adam', metrics=['mae', 'mape'])
  return model


model = create_model()
model.summary()

path = '/content/drive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding2.hdf5'

callback = tf.keras.callbacks.ModelCheckpoint(path, 
                                              monitor='val_loss', 
                                              save_best_only=True, 
                                              verbose=1)

history = model.fit(X_train, y_train, 
                    batch_size=batch_size, 
                    epochs=20, 
                    callbacks=[callback],
                    validation_data=(X_val, y_val))
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 128, 5)]     0           []
#
#  time2_vector_6 (Time2Vector)   (None, 128, 2)       512         ['input_6[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 128, 7)       0           ['input_6[0][0]',
#                                                                   'time2_vector_6[0][0]']
#
#  transformer_encoder_18 (Transf  (None, 128, 7)      99114       ['concatenate_5[0][0]',
#  ormerEncoder)                                                    'concatenate_5[0][0]',
#                                                                   'concatenate_5[0][0]']
#
#  transformer_encoder_19 (Transf  (None, 128, 7)      99114       ['transformer_encoder_18[0][0]',
#  ormerEncoder)                                                    'transformer_encoder_18[0][0]',
#                                                                   'transformer_encoder_18[0][0]']
#
#  transformer_encoder_20 (Transf  (None, 128, 7)      99114       ['transformer_encoder_19[0][0]',
#  ormerEncoder)                                                    'transformer_encoder_19[0][0]',
#                                                                   'transformer_encoder_19[0][0]']
#
#  global_average_pooling1d_5 (Gl  (None, 128)         0           ['transformer_encoder_20[0][0]']
#  obalAveragePooling1D)
#
#  dropout_10 (Dropout)           (None, 128)          0           ['global_average_pooling1d_5[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 64)           8256        ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 64)           0           ['dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 1)            65          ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 306,175
# Trainable params: 306,175
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0111 - mae: 0.0647 - mape: 13.4002
# Epoch 1: val_loss improved from inf to 0.00059, saving model to /content/gdrive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding2.hdf5
# 511/511 [==============================] - 429s 716ms/step - loss: 0.0111 - mae: 0.0647 - mape: 13.4002 - val_loss: 5.8907e-04 - val_mae: 0.0215 - val_mape: 4.3667
# Epoch 2/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0025 - mae: 0.0402 - mape: 8.3358
# Epoch 2: val_loss improved from 0.00059 to 0.00016, saving model to /content/gdrive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding2.hdf5
# 511/511 [==============================] - 357s 697ms/step - loss: 0.0025 - mae: 0.0402 - mape: 8.3358 - val_loss: 1.5792e-04 - val_mae: 0.0083 - val_mape: 1.6714
# Epoch 3/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0020 - mae: 0.0355 - mape: 7.3712
# Epoch 3: val_loss did not improve from 0.00016
# 511/511 [==============================] - 354s 692ms/step - loss: 0.0020 - mae: 0.0355 - mape: 7.3712 - val_loss: 2.1711e-04 - val_mae: 0.0108 - val_mape: 2.1846
# Epoch 4/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0304 - mape: 6.3050
# Epoch 4: val_loss improved from 0.00016 to 0.00014, saving model to /content/gdrive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding2.hdf5
# 511/511 [==============================] - 352s 690ms/step - loss: 0.0015 - mae: 0.0304 - mape: 6.3050 - val_loss: 1.4217e-04 - val_mae: 0.0075 - val_mape: 1.5325
# Epoch 5/20
# 511/511 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0268 - mape: 5.5730
# Epoch 5: val_loss did not improve from 0.00014
# 511/511 [==============================] - 358s 701ms/step - loss: 0.0012 - mae: 0.0268 - mape: 5.5730 - val_loss: 2.1852e-04 - val_mae: 0.0109 - val_mape: 2.1954
# Epoch 6/20
# 511/511 [==============================] - ETA: 0s - loss: 9.2873e-04 - mae: 0.0237 - mape: 4.9390
# Epoch 6: val_loss improved from 0.00014 to 0.00014, saving model to /content/gdrive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding2.hdf5
# 511/511 [==============================] - 354s 693ms/step - loss: 9.2873e-04 - mae: 0.0237 - mape: 4.9390 - val_loss: 1.3823e-04 - val_mae: 0.0076 - val_mape: 1.5583
# Epoch 7/20
# 511/511 [==============================] - ETA: 0s - loss: 7.5410e-04 - mae: 0.0209 - mape: 4.3478
# Epoch 7: val_loss did not improve from 0.00014
# 511/511 [==============================] - 351s 686ms/step - loss: 7.5410e-04 - mae: 0.0209 - mape: 4.3478 - val_loss: 1.5278e-04 - val_mae: 0.0080 - val_mape: 1.6218
# Epoch 8/20
# 511/511 [==============================] - ETA: 0s - loss: 6.3275e-04 - mae: 0.0189 - mape: 3.9348
# Epoch 8: val_loss did not improve from 0.00014
# 511/511 [==============================] - 350s 685ms/step - loss: 6.3275e-04 - mae: 0.0189 - mape: 3.9348 - val_loss: 1.7897e-04 - val_mae: 0.0092 - val_mape: 1.8662
# Epoch 9/20
# 511/511 [==============================] - ETA: 0s - loss: 5.5946e-04 - mae: 0.0174 - mape: 3.6379
# Epoch 9: val_loss did not improve from 0.00014
# 511/511 [==============================] - 349s 683ms/step - loss: 5.5946e-04 - mae: 0.0174 - mape: 3.6379 - val_loss: 1.4003e-04 - val_mae: 0.0081 - val_mape: 1.6487
# Epoch 10/20
# 511/511 [==============================] - ETA: 0s - loss: 5.3023e-04 - mae: 0.0168 - mape: 3.5022
# Epoch 10: val_loss did not improve from 0.00014
# 511/511 [==============================] - 393s 769ms/step - loss: 5.3023e-04 - mae: 0.0168 - mape: 3.5022 - val_loss: 1.4416e-04 - val_mae: 0.0076 - val_mape: 1.5456
# Epoch 11/20
# 511/511 [==============================] - ETA: 0s - loss: 5.1678e-04 - mae: 0.0164 - mape: 3.4244
# Epoch 11: val_loss did not improve from 0.00014
# 511/511 [==============================] - 397s 777ms/step - loss: 5.1678e-04 - mae: 0.0164 - mape: 3.4244 - val_loss: 1.7996e-04 - val_mae: 0.0093 - val_mape: 1.8747
# Epoch 12/20
# 511/511 [==============================] - ETA: 0s - loss: 5.1096e-04 - mae: 0.0163 - mape: 3.3980
# Epoch 12: val_loss did not improve from 0.00014
# 511/511 [==============================] - 399s 781ms/step - loss: 5.1096e-04 - mae: 0.0163 - mape: 3.3980 - val_loss: 1.4183e-04 - val_mae: 0.0075 - val_mape: 1.5312
# Epoch 13/20
# 511/511 [==============================] - ETA: 0s - loss: 5.0793e-04 - mae: 0.0162 - mape: 3.3803
# Epoch 13: val_loss did not improve from 0.00014
# 511/511 [==============================] - 394s 771ms/step - loss: 5.0793e-04 - mae: 0.0162 - mape: 3.3803 - val_loss: 1.5705e-04 - val_mae: 0.0082 - val_mape: 1.6619
# Epoch 14/20
# 511/511 [==============================] - ETA: 0s - loss: 5.0625e-04 - mae: 0.0161 - mape: 3.3729
# Epoch 14: val_loss did not improve from 0.00014
# 511/511 [==============================] - 401s 786ms/step - loss: 5.0625e-04 - mae: 0.0161 - mape: 3.3729 - val_loss: 1.5287e-04 - val_mae: 0.0080 - val_mape: 1.6223
# Epoch 15/20
# 511/511 [==============================] - ETA: 0s - loss: 5.0626e-04 - mae: 0.0161 - mape: 3.3727
# Epoch 15: val_loss did not improve from 0.00014
# 511/511 [==============================] - 401s 785ms/step - loss: 5.0626e-04 - mae: 0.0161 - mape: 3.3727 - val_loss: 1.4312e-04 - val_mae: 0.0076 - val_mape: 1.5380
# Epoch 16/20
# 511/511 [==============================] - ETA: 0s - loss: 5.0681e-04 - mae: 0.0161 - mape: 3.3741
# Epoch 16: val_loss did not improve from 0.00014
# 511/511 [==============================] - 355s 695ms/step - loss: 5.0681e-04 - mae: 0.0161 - mape: 3.3741 - val_loss: 1.3937e-04 - val_mae: 0.0075 - val_mape: 1.5333
# Epoch 17/20
# 511/511 [==============================] - ETA: 0s - loss: 5.0612e-04 - mae: 0.0161 - mape: 3.3712
# Epoch 17: val_loss did not improve from 0.00014
# 511/511 [==============================] - 353s 691ms/step - loss: 5.0612e-04 - mae: 0.0161 - mape: 3.3712 - val_loss: 1.4497e-04 - val_mae: 0.0076 - val_mape: 1.5516
# Epoch 18/20
# 511/511 [==============================] - ETA: 0s - loss: 5.0632e-04 - mae: 0.0162 - mape: 3.3786
# Epoch 18: val_loss did not improve from 0.00014
# 511/511 [==============================] - 354s 693ms/step - loss: 5.0632e-04 - mae: 0.0162 - mape: 3.3786 - val_loss: 1.5931e-04 - val_mae: 0.0083 - val_mape: 1.6836
# Epoch 19/20
# 511/511 [==============================] - ETA: 0s - loss: 5.0713e-04 - mae: 0.0161 - mape: 3.3754
# Epoch 19: val_loss did not improve from 0.00014
# 511/511 [==============================] - 357s 698ms/step - loss: 5.0713e-04 - mae: 0.0161 - mape: 3.3754 - val_loss: 1.4313e-04 - val_mae: 0.0076 - val_mape: 1.5381
# Epoch 20/20
# 511/511 [==============================] - ETA: 0s - loss: 5.0632e-04 - mae: 0.0161 - mape: 3.3725
# Epoch 20: val_loss did not improve from 0.00014
# 511/511 [==============================] - 356s 696ms/step - loss: 5.0632e-04 - mae: 0.0161 - mape: 3.3725 - val_loss: 1.4050e-04 - val_mae: 0.0075 - val_mape: 1.5287

# %%
path = '/content/drive/MyDrive/UChicago_Project/Machine_Learning/Transformer+TimeEmbedding2.hdf5'
model = tf.keras.models.load_model(path,
                                   custom_objects={'Time2Vector': Time2Vector, 
                                                   'SingleAttention': SingleAttention,
                                                   'MultiAttention': MultiAttention,
                                                   'TransformerEncoder': TransformerEncoder})

# %%
#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))
# Out:
# 511/511 [==============================] - 154s 291ms/step
# 61/61 [==============================] - 19s 307ms/step
# 61/61 [==============================] - 17s 286ms/step
#
# Evaluation metrics
# Training Data - Loss: 0.0005, MAE: 0.0161, MAPE: 3.3726
# Validation Data - Loss: 0.0001, MAE: 0.0075, MAPE: 1.5287
# Test Data - Loss: 0.0003, MAE: 0.0111, MAPE: 2.2746

# %%
fig = plt.figure(figsize=(15,20))

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='BTC Closing Returns')
ax11.plot(np.arange(seq_len, train_pred.shape[0]+seq_len), train_pred, linewidth=3, label='Predicted BTC Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('BTC Closing Returns')
ax11.legend(loc="best", fontsize=12)

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='BTC Closing Returns')
ax21.plot(np.arange(seq_len, val_pred.shape[0]+seq_len), val_pred, linewidth=3, label='Predicted BTC Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')
ax21.legend(loc="best", fontsize=12)

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='BTC Closing Returns')
ax31.plot(np.arange(seq_len, test_pred.shape[0]+seq_len), test_pred, linewidth=3, label='Predicted BTC Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('BTC Closing Returns')
ax31.legend(loc="best", fontsize=12)

# %%
fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Moving Average - Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
ax1.plot(history.history['loss'], label='Training loss (MSE)')
ax1.set_title("Model loss", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (MSE)')
ax1.legend(loc="best", fontsize=12)

#Plot MAE
ax2 = fig.add_subplot(312)
ax2.plot(history.history['mae'], label='Training MAE')
ax2.set_title("Model metric - Mean average error (MAE)", fontsize=18)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean average error (MAE)')
ax2.legend(loc="best", fontsize=12)

#Plot MAPE
ax3 = fig.add_subplot(313)
ax3.plot(history.history['mape'], label='Training MAPE')
ax3.set_title("Model metric - Mean average percentage error (MAPE)", fontsize=18)
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Mean average percentage error (MAPE)')
ax3.legend(loc="best", fontsize=12)

# %%
fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Moving Average - Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
#ax1.plot(history.history['loss'][:9], label='Training loss (MSE)')
ax1.plot(history.history['val_loss'], label='Validation loss (MSE)')
ax1.set_title("Model loss", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (MSE)')
ax1.legend(loc="best", fontsize=12)

#Plot MAE
ax2 = fig.add_subplot(312)
ax2.plot(history.history['val_mae'], label='Validation MAE')
ax2.set_title("Model metric - Mean average error (MAE)", fontsize=18)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean average error (MAE)')
ax2.legend(loc="best", fontsize=12)

#Plot MAPE
ax3 = fig.add_subplot(313)
ax3.plot(history.history['val_mape'], label='Validation MAPE')
ax3.set_title("Model metric - Mean average percentage error (MAPE)", fontsize=18)
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Mean average percentage error (MAPE)')
ax3.legend(loc="best", fontsize=12)
